# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

# %%
from alpha_vantage.fundamentaldata import FundamentalData
from alpha_vantage.timeseries import TimeSeries
import numpy as np
import pandas as pd
from pandas import DataFrame as df, Timestamp
import csv
import time
#import module for mysql 
import os
from os import path
import mysql.connector as mysql
from CalFundamental import calFund
from APICall import ApiCalling, ApiKeyDistribute
from mysqlProc import createTableSQL, insertTableSQL
from playsound import playsound


def makeFolder() :
    # define the name of the directory to be created
    path = "/Varians"
    #creating folder:
    try:
        os.makedirs(path)
    except OSError:
        print ("Directory %s already exist" % path)
    else:
        print ("Successfully created the directory %s" % path)

def stocklisting() :
    with open(r'stocklist.csv') as slist:
        stocklist = pd.read_csv(slist, header = None)    
    stocklist = stocklist.rename(columns={0 : 'company', 1 : 'market', 2 : 'ticker'})
    stocklist.ticker = stocklist.ticker.str.strip()
    return stocklist.ticker

if __name__ == "__main__":        
    #check and create folder varians as temporary storage
#     serverHost = "remotemysql.com"
#     userInput = "0NMKbNP49w"
#     mysqlPassword = "uh7eChPxHw"
#     db_name = "0NMKbNP49w"
    serverHost = "localhost"
    userInput = "root"
    mysqlPassword = "minyak23"
    db_name = "newstockmarket"
    API_KEY_TEST = "G23MAAVKWB5TMPMV"
    makeFolder()
    stocklist = stocklisting()
    
    #creating table in mysql database, insert password accordingly
    createTableSQL(serverHost, userInput, mysqlPassword, db_name)
    
    for zticker in list (stocklist) :
        entity = str(zticker)
        print ("Stock Ticker Name : "+ entity)
    
        #reset data memory
        OV_reader = pd.DataFrame()
        ISQ_reader = pd.DataFrame()
        CFQ_reader = pd.DataFrame()
        BSQ_reader = pd.DataFrame()
        dict_table = pd.DataFrame()

        #API calling
        API_KEY_TEST = ApiKeyDistribute().randomize(API_KEY_TEST)
        e = ApiCalling(zticker, API_KEY_TEST).step_1()
        ApiCalling(zticker, API_KEY_TEST).step_2(e)
        ApiCalling(zticker, API_KEY_TEST).step_3(e)
        ApiCalling(zticker, API_KEY_TEST).step_4(e)
        ApiCalling(zticker, API_KEY_TEST).step_5(e)

        if e != 'Skip Ticker' :

            try :
                Calculation, CFQ_reader, ISQ_reader, BSQ_reader, OV_reader = calFund()
                #preparing pandas dataframe to list inputing to mysql
                insertTableSQL(serverHost, userInput, mysqlPassword, db_name, entity, Calculation, CFQ_reader, ISQ_reader, BSQ_reader, OV_reader)
                
            except TypeError as e :
                continue
            playsound('alert.wav')
# Out:
# Directory /Varians already exist
# Stock Ticker Name : STLA
# API key is : 6PE06AMZAM1MCGFX
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Invalid API call. Please retry or visit the documentation (https://www.alphavantage.co/documentation/) for TIME_SERIES_MONTHLY_ADJUSTED.
# API key is : 6HZYCBP71FGOR1O5
# C:\Users\myanu\Google Drive\Programming\Python\PYTHON_NOTEBOOK\Varians\RemoteMySQL\CalFundamental.py:107: RuntimeWarning: invalid value encountered in true_divide
#   EPStemps = [Tableeps.NIQ[i]/Tableeps.SOQ[i] for i in range(len(Tableeps.SOQ))]
# C:\Users\myanu\Google Drive\Programming\Python\PYTHON_NOTEBOOK\Varians\RemoteMySQL\CalFundamental.py:145: RuntimeWarning: invalid value encountered in double_scalars
#   Calculation ['EPS'] = [inputcalc.netIncome[i]/inputcalc.SO[i] for i in range(len(inputcalc.SO))]
# C:\Users\myanu\Google Drive\Programming\Python\PYTHON_NOTEBOOK\Varians\RemoteMySQL\CalFundamental.py:156: RuntimeWarning: divide by zero encountered in double_scalars
#   Calculation ['PER'] = [inputcalc.LastPrice[i]/temp.EPSTTM[i] for i in range(len(inputcalc.SO))]
# C:\Users\myanu\Google Drive\Programming\Python\PYTHON_NOTEBOOK\Varians\RemoteMySQL\CalFundamental.py:157: RuntimeWarning: invalid value encountered in double_scalars
#   Calculation ['BVPS'] = [(inputcalc.TA[i]-inputcalc.TL[i])/inputcalc.SO[i] for i in range(len(inputcalc.SO))]
# C:\Users\myanu\Google Drive\Programming\Python\PYTHON_NOTEBOOK\Varians\RemoteMySQL\CalFundamental.py:159: RuntimeWarning: invalid value encountered in double_scalars
#   Calculation ['ROA%'] = [temp.NITTM[i]/inputcalc.TA[i]*100 for i in range(len(inputcalc.SO))]
# C:\Users\myanu\Google Drive\Programming\Python\PYTHON_NOTEBOOK\Varians\RemoteMySQL\CalFundamental.py:160: RuntimeWarning: invalid value encountered in double_scalars
#   Calculation ['ROE%'] = [temp.NITTM[i]/inputcalc.TSE[i]*100 for i in range(len(inputcalc.SO))]
# C:\Users\myanu\Google Drive\Programming\Python\PYTHON_NOTEBOOK\Varians\RemoteMySQL\CalFundamental.py:163: RuntimeWarning: invalid value encountered in double_scalars
#   Calculation ['EV/EBITDA'] = [Calculation.EV[i]/Calculation.EBITDA[i] for i in range(len(inputcalc.SO))]
# C:\Users\myanu\Google Drive\Programming\Python\PYTHON_NOTEBOOK\Varians\RemoteMySQL\CalFundamental.py:164: RuntimeWarning: invalid value encountered in double_scalars
#   Calculation ['D/E'] = [inputcalc.TL[i]/inputcalc.TSE[i] for i in range(len(inputcalc.TL))]
# C:\Users\myanu\Google Drive\Programming\Python\PYTHON_NOTEBOOK\Varians\RemoteMySQL\CalFundamental.py:165: RuntimeWarning: invalid value encountered in double_scalars
#   Calculation ['Debt/Totalcap'] = [(inputcalc.STD[i]+inputcalc.LTD[i])/(inputcalc.STD[i]+inputcalc.LTD[i]+inputcalc.TSE[i]) for i in range(len(inputcalc.STD))]
# C:\Users\myanu\Google Drive\Programming\Python\PYTHON_NOTEBOOK\Varians\RemoteMySQL\CalFundamental.py:166: RuntimeWarning: invalid value encountered in double_scalars
#   Calculation ['Debt/EBITDA'] = [(inputcalc.STD[i]+inputcalc.LTD[i])/Calculation.EBITDA[i] for i in range(len(inputcalc.STD)) ]
# Stock Ticker Name : HYMTF
# API key is : 6HZYCBP71FGOR1O5
# Error getting data from the api, no return was given.
# Problem Ticker Name : HYMTF ...Skipping
# Skip step_2
# Skip step_3
# Skip step_4
# Skip step_5
# Stock Ticker Name : HMC
# API key is : X5LNMI2AESR1YQCU
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : YBBKWRK4VSTP4GZH
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X3Z3LQ31Z9B1OYX9
# Succsesfully Pull Data Timeseries from web
# C:\Users\myanu\Google Drive\Programming\Python\PYTHON_NOTEBOOK\Varians\RemoteMySQL\CalFundamental.py:158: RuntimeWarning: divide by zero encountered in double_scalars
#   Calculation ['PBV'] = [Calculation.LastPrice[i]/Calculation.BVPS[i] for i in range(len(inputcalc.SO))]
# C:\Users\myanu\Google Drive\Programming\Python\PYTHON_NOTEBOOK\Varians\RemoteMySQL\CalFundamental.py:159: RuntimeWarning: divide by zero encountered in double_scalars
#   Calculation ['ROA%'] = [temp.NITTM[i]/inputcalc.TA[i]*100 for i in range(len(inputcalc.SO))]
# C:\Users\myanu\Google Drive\Programming\Python\PYTHON_NOTEBOOK\Varians\RemoteMySQL\CalFundamental.py:163: RuntimeWarning: divide by zero encountered in double_scalars
#   Calculation ['EV/EBITDA'] = [Calculation.EV[i]/Calculation.EBITDA[i] for i in range(len(inputcalc.SO))]
# C:\Users\myanu\Google Drive\Programming\Python\PYTHON_NOTEBOOK\Varians\RemoteMySQL\CalFundamental.py:166: RuntimeWarning: divide by zero encountered in double_scalars
#   Calculation ['Debt/EBITDA'] = [(inputcalc.STD[i]+inputcalc.LTD[i])/Calculation.EBITDA[i] for i in range(len(inputcalc.STD)) ]
# Stock Ticker Name : F
# API key is : YBBKWRK4VSTP4GZH
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X3Z3LQ31Z9B1OYX9
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : G23MAAVKWB5TMPMV
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : SZKMF
# API key is : X3Z3LQ31Z9B1OYX9
# Error getting data from the api, no return was given.
# Problem Ticker Name : SZKMF ...Skipping
# Skip step_2
# Skip step_3
# Skip step_4
# Skip step_5
# Stock Ticker Name : NSANY
# API key is : G23MAAVKWB5TMPMV
# Error getting data from the api, no return was given.
# Problem Ticker Name : NSANY ...Skipping
# Skip step_2
# Skip step_3
# Skip step_4
# Skip step_5
# Stock Ticker Name : FUJHY
# API key is : 6PE06AMZAM1MCGFX
# Error getting data from the api, no return was given.
# Problem Ticker Name : FUJHY ...Skipping
# Skip step_2
# Skip step_3
# Skip step_4
# Skip step_5
# Stock Ticker Name : AAPL
# API key is : 6HZYCBP71FGOR1O5
# Succsesfully Pull Data Income Statement from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X5LNMI2AESR1YQCU
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : YBBKWRK4VSTP4GZH
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X3Z3LQ31Z9B1OYX9
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : SSNHY
# API key is : X5LNMI2AESR1YQCU
# Error getting data from the api, no return was given.
# Problem Ticker Name : SSNHY ...Skipping
# Skip step_2
# Skip step_3
# Skip step_4
# Skip step_5
# Stock Ticker Name : GOOG
# API key is : YBBKWRK4VSTP4GZH
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# Skip step_1
# API key is : X3Z3LQ31Z9B1OYX9
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# Skip step_1
# API key is : G23MAAVKWB5TMPMV
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : MSFT
# API key is : X3Z3LQ31Z9B1OYX9
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# Skip step_1
# API key is : G23MAAVKWB5TMPMV
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# Skip step_1
# API key is : 6PE06AMZAM1MCGFX
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : DEL
# API key is : G23MAAVKWB5TMPMV
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# Skip step_1
# API key is : 6PE06AMZAM1MCGFX
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# Skip step_1
# API key is : 6HZYCBP71FGOR1O5
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# C:\Users\myanu\Google Drive\Programming\Python\PYTHON_NOTEBOOK\Varians\RemoteMySQL\CalFundamental.py:107: RuntimeWarning: divide by zero encountered in true_divide
#   EPStemps = [Tableeps.NIQ[i]/Tableeps.SOQ[i] for i in range(len(Tableeps.SOQ))]
# C:\Users\myanu\Google Drive\Programming\Python\PYTHON_NOTEBOOK\Varians\RemoteMySQL\CalFundamental.py:145: RuntimeWarning: divide by zero encountered in double_scalars
#   Calculation ['EPS'] = [inputcalc.netIncome[i]/inputcalc.SO[i] for i in range(len(inputcalc.SO))]
# C:\Users\myanu\Google Drive\Programming\Python\PYTHON_NOTEBOOK\Varians\RemoteMySQL\CalFundamental.py:157: RuntimeWarning: divide by zero encountered in double_scalars
#   Calculation ['BVPS'] = [(inputcalc.TA[i]-inputcalc.TL[i])/inputcalc.SO[i] for i in range(len(inputcalc.SO))]
# Stock Ticker Name : SNE
# API key is : 6PE06AMZAM1MCGFX
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# Skip step_1
# API key is : 6HZYCBP71FGOR1O5
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# Skip step_1
# API key is : X5LNMI2AESR1YQCU
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : IBM
# API key is : 6HZYCBP71FGOR1O5
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# Skip step_1
# API key is : X5LNMI2AESR1YQCU
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# Skip step_1
# API key is : YBBKWRK4VSTP4GZH
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : INTC
# API key is : X5LNMI2AESR1YQCU
# Succsesfully Pull Data Income Statement from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : YBBKWRK4VSTP4GZH
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X3Z3LQ31Z9B1OYX9
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : G23MAAVKWB5TMPMV
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : FB
# API key is : YBBKWRK4VSTP4GZH
# Succsesfully Pull Data Income Statement from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X3Z3LQ31Z9B1OYX9
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : G23MAAVKWB5TMPMV
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : CSCO
# API key is : X3Z3LQ31Z9B1OYX9
# Succsesfully Pull Data Income Statement from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : G23MAAVKWB5TMPMV
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : 6PE06AMZAM1MCGFX
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : ORCL
# API key is : G23MAAVKWB5TMPMV
# Succsesfully Pull Data Income Statement from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : 6PE06AMZAM1MCGFX
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : 6HZYCBP71FGOR1O5
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : SAP
# API key is : 6PE06AMZAM1MCGFX
# Succsesfully Pull Data Income Statement from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : 6HZYCBP71FGOR1O5
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X5LNMI2AESR1YQCU
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : ADBE
# API key is : 6HZYCBP71FGOR1O5
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X5LNMI2AESR1YQCU
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : YBBKWRK4VSTP4GZH
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X3Z3LQ31Z9B1OYX9
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : NFLX
# API key is : X5LNMI2AESR1YQCU
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : YBBKWRK4VSTP4GZH
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X3Z3LQ31Z9B1OYX9
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : HPQ
# API key is : YBBKWRK4VSTP4GZH
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X3Z3LQ31Z9B1OYX9
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : G23MAAVKWB5TMPMV
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : JNJ
# API key is : X3Z3LQ31Z9B1OYX9
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : G23MAAVKWB5TMPMV
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : 6PE06AMZAM1MCGFX
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : ROG
# API key is : G23MAAVKWB5TMPMV
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : 6PE06AMZAM1MCGFX
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : 6HZYCBP71FGOR1O5
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : NVS
# API key is : 6PE06AMZAM1MCGFX
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : 6HZYCBP71FGOR1O5
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X5LNMI2AESR1YQCU
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : PFE
# API key is : 6HZYCBP71FGOR1O5
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X5LNMI2AESR1YQCU
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : YBBKWRK4VSTP4GZH
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : MRK
# API key is : X5LNMI2AESR1YQCU
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : YBBKWRK4VSTP4GZH
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X3Z3LQ31Z9B1OYX9
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : G23MAAVKWB5TMPMV
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : ABT
# API key is : YBBKWRK4VSTP4GZH
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X3Z3LQ31Z9B1OYX9
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : G23MAAVKWB5TMPMV
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : NVO
# API key is : X3Z3LQ31Z9B1OYX9
# Succsesfully Pull Data Income Statement from web
# Invalid API call. Please retry or visit the documentation (https://www.alphavantage.co/documentation/) for CASH_FLOW.
# API key is : G23MAAVKWB5TMPMV
# Invalid API call. Please retry or visit the documentation (https://www.alphavantage.co/documentation/) for CASH_FLOW.
# API key is : 6PE06AMZAM1MCGFX
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : AZN
# API key is : G23MAAVKWB5TMPMV
# Invalid API call. Please retry or visit the documentation (https://www.alphavantage.co/documentation/) for INCOME_STATEMENT.
# Skip step_1
# API key is : 6PE06AMZAM1MCGFX
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# Skip step_1
# API key is : 6HZYCBP71FGOR1O5
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : BAYN
# API key is : 6PE06AMZAM1MCGFX
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# Skip step_1
# API key is : 6HZYCBP71FGOR1O5
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# Skip step_1
# API key is : X5LNMI2AESR1YQCU
# Error getting data from the api, no return was given.
# Problem Ticker Name : BAYN ...Skipping
# Skip step_2
# Skip step_3
# Skip step_4
# Skip step_5
# Stock Ticker Name : GSK
# API key is : 6HZYCBP71FGOR1O5
# Invalid API call. Please retry or visit the documentation (https://www.alphavantage.co/documentation/) for INCOME_STATEMENT.
# Skip step_1
# API key is : X5LNMI2AESR1YQCU
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X5LNMI2AESR1YQCU
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : YBBKWRK4VSTP4GZH
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : GLD
# API key is : X5LNMI2AESR1YQCU
# Error getting data from the api, no return was given.
# Problem Ticker Name : GLD ...Skipping
# Skip step_2
# Skip step_3
# Skip step_4
# Skip step_5
# Stock Ticker Name : SNY
# API key is : YBBKWRK4VSTP4GZH
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X3Z3LQ31Z9B1OYX9
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : G23MAAVKWB5TMPMV
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# C:\Users\myanu\Google Drive\Programming\Python\PYTHON_NOTEBOOK\Varians\RemoteMySQL\CalFundamental.py:107: RuntimeWarning: divide by zero encountered in double_scalars
#   EPStemps = [Tableeps.NIQ[i]/Tableeps.SOQ[i] for i in range(len(Tableeps.SOQ))]
# C:\Users\myanu\Google Drive\Programming\Python\PYTHON_NOTEBOOK\Varians\RemoteMySQL\CalFundamental.py:107: RuntimeWarning: invalid value encountered in double_scalars
#   EPStemps = [Tableeps.NIQ[i]/Tableeps.SOQ[i] for i in range(len(Tableeps.SOQ))]
# C:\Users\myanu\Google Drive\Programming\Python\PYTHON_NOTEBOOK\Varians\RemoteMySQL\CalFundamental.py:160: RuntimeWarning: divide by zero encountered in double_scalars
#   Calculation ['ROE%'] = [temp.NITTM[i]/inputcalc.TSE[i]*100 for i in range(len(inputcalc.SO))]
# C:\Users\myanu\Google Drive\Programming\Python\PYTHON_NOTEBOOK\Varians\RemoteMySQL\CalFundamental.py:164: RuntimeWarning: divide by zero encountered in double_scalars
#   Calculation ['D/E'] = [inputcalc.TL[i]/inputcalc.TSE[i] for i in range(len(inputcalc.TL))]
# Stock Ticker Name : VRTX
# API key is : X3Z3LQ31Z9B1OYX9
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : G23MAAVKWB5TMPMV
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : 6PE06AMZAM1MCGFX
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : ZTS
# API key is : G23MAAVKWB5TMPMV
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : 6PE06AMZAM1MCGFX
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : 6HZYCBP71FGOR1O5
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : AMGN
# API key is : 6PE06AMZAM1MCGFX
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : 6HZYCBP71FGOR1O5
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X5LNMI2AESR1YQCU
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : XOM
# API key is : 6HZYCBP71FGOR1O5
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X5LNMI2AESR1YQCU
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : YBBKWRK4VSTP4GZH
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X3Z3LQ31Z9B1OYX9
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : CVX
# API key is : X5LNMI2AESR1YQCU
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : YBBKWRK4VSTP4GZH
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X3Z3LQ31Z9B1OYX9
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : EPD
# API key is : YBBKWRK4VSTP4GZH
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X3Z3LQ31Z9B1OYX9
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : G23MAAVKWB5TMPMV
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : COP
# API key is : X3Z3LQ31Z9B1OYX9
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : G23MAAVKWB5TMPMV
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : 6PE06AMZAM1MCGFX
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : EOG
# API key is : G23MAAVKWB5TMPMV
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : 6PE06AMZAM1MCGFX
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : 6HZYCBP71FGOR1O5
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : OXY
# API key is : 6PE06AMZAM1MCGFX
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : 6HZYCBP71FGOR1O5
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X5LNMI2AESR1YQCU
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : KMI
# API key is : 6HZYCBP71FGOR1O5
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X5LNMI2AESR1YQCU
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : YBBKWRK4VSTP4GZH
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : HAL
# API key is : X5LNMI2AESR1YQCU
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : YBBKWRK4VSTP4GZH
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X3Z3LQ31Z9B1OYX9
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : G23MAAVKWB5TMPMV
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : BP
# API key is : YBBKWRK4VSTP4GZH
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X3Z3LQ31Z9B1OYX9
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : G23MAAVKWB5TMPMV
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : EQNR
# API key is : X3Z3LQ31Z9B1OYX9
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : G23MAAVKWB5TMPMV
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : 6PE06AMZAM1MCGFX
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : JKS
# API key is : G23MAAVKWB5TMPMV
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : 6PE06AMZAM1MCGFX
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : 6HZYCBP71FGOR1O5
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : BEP
# API key is : 6PE06AMZAM1MCGFX
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : 6HZYCBP71FGOR1O5
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X5LNMI2AESR1YQCU
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : FSLR
# API key is : 6HZYCBP71FGOR1O5
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X5LNMI2AESR1YQCU
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : YBBKWRK4VSTP4GZH
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X3Z3LQ31Z9B1OYX9
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : CSIQ
# API key is : X5LNMI2AESR1YQCU
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : YBBKWRK4VSTP4GZH
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X3Z3LQ31Z9B1OYX9
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : REGI
# API key is : YBBKWRK4VSTP4GZH
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X3Z3LQ31Z9B1OYX9
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : G23MAAVKWB5TMPMV
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : SPWR
# API key is : X3Z3LQ31Z9B1OYX9
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : G23MAAVKWB5TMPMV
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : 6PE06AMZAM1MCGFX
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : AMZN
# API key is : G23MAAVKWB5TMPMV
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : 6PE06AMZAM1MCGFX
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : 6HZYCBP71FGOR1O5
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X5LNMI2AESR1YQCU
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : EBAY
# API key is : 6PE06AMZAM1MCGFX
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : 6HZYCBP71FGOR1O5
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X5LNMI2AESR1YQCU
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : BABA
# API key is : 6HZYCBP71FGOR1O5
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X5LNMI2AESR1YQCU
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : YBBKWRK4VSTP4GZH
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : JD
# API key is : X5LNMI2AESR1YQCU
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : YBBKWRK4VSTP4GZH
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X3Z3LQ31Z9B1OYX9
# ...
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X5LNMI2AESR1YQCU
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : YBBKWRK4VSTP4GZH
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X3Z3LQ31Z9B1OYX9
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : G23MAAVKWB5TMPMV
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : 6PE06AMZAM1MCGFX
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : 6HZYCBP71FGOR1O5
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X5LNMI2AESR1YQCU
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : YBBKWRK4VSTP4GZH
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X3Z3LQ31Z9B1OYX9
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : G23MAAVKWB5TMPMV
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : 6PE06AMZAM1MCGFX
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : 6HZYCBP71FGOR1O5
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X5LNMI2AESR1YQCU
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : YBBKWRK4VSTP4GZH
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X3Z3LQ31Z9B1OYX9
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : G23MAAVKWB5TMPMV
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : 6PE06AMZAM1MCGFX
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : 6HZYCBP71FGOR1O5
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X5LNMI2AESR1YQCU
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : YBBKWRK4VSTP4GZH
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X3Z3LQ31Z9B1OYX9
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : G23MAAVKWB5TMPMV
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : 6PE06AMZAM1MCGFX
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : 6HZYCBP71FGOR1O5
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X5LNMI2AESR1YQCU
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : YBBKWRK4VSTP4GZH
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X3Z3LQ31Z9B1OYX9
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : G23MAAVKWB5TMPMV
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : 6PE06AMZAM1MCGFX
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : 6HZYCBP71FGOR1O5
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : X5LNMI2AESR1YQCU
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# API key is : YBBKWRK4VSTP4GZH
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : GRPN
# API key is : YBBKWRK4VSTP4GZH
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : OSTK
# API key is : X3Z3LQ31Z9B1OYX9
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# Skip step_1
# API key is : G23MAAVKWB5TMPMV
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# Skip step_1
# API key is : 6PE06AMZAM1MCGFX
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# Skip step_1
# API key is : 6HZYCBP71FGOR1O5
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : CVNA
# API key is : G23MAAVKWB5TMPMV
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# Skip step_1
# API key is : 6PE06AMZAM1MCGFX
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# Skip step_1
# API key is : 6HZYCBP71FGOR1O5
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : CHWY
# API key is : 6PE06AMZAM1MCGFX
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# Skip step_1
# API key is : 6HZYCBP71FGOR1O5
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# Skip step_1
# API key is : X5LNMI2AESR1YQCU
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : TGT
# API key is : 6HZYCBP71FGOR1O5
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# Skip step_1
# API key is : X5LNMI2AESR1YQCU
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# Skip step_1
# API key is : YBBKWRK4VSTP4GZH
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : WMT
# API key is : X5LNMI2AESR1YQCU
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# Skip step_1
# API key is : YBBKWRK4VSTP4GZH
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# Skip step_1
# API key is : X3Z3LQ31Z9B1OYX9
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# Skip step_1
# API key is : G23MAAVKWB5TMPMV
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : W
# API key is : YBBKWRK4VSTP4GZH
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# Skip step_1
# API key is : X3Z3LQ31Z9B1OYX9
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# Skip step_1
# API key is : G23MAAVKWB5TMPMV
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : M
# API key is : X3Z3LQ31Z9B1OYX9
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# Skip step_1
# API key is : G23MAAVKWB5TMPMV
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# Skip step_1
# API key is : 6PE06AMZAM1MCGFX
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : COST
# API key is : G23MAAVKWB5TMPMV
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# Skip step_1
# API key is : 6PE06AMZAM1MCGFX
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# Skip step_1
# API key is : 6HZYCBP71FGOR1O5
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web
# Stock Ticker Name : BBY
# API key is : 6PE06AMZAM1MCGFX
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# Skip step_1
# API key is : 6HZYCBP71FGOR1O5
# Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.
# Skip step_1
# API key is : X5LNMI2AESR1YQCU
# Succsesfully Pull Data Income Statement from web
# Succsesfully Pull Data Cash Flow from web
# Succsesfully Pull Data Balance Sheet from web
# Succsesfully Pull Data Overview from web
# Succsesfully Pull Data Timeseries from web

# %%
##Script to drop table 
import mysql.connector as mysql

def connect():
    try:
        return mysql.connect(
#             host='remotemysql.com',
#             user='0NMKbNP49w',
#             password="uh7eChPxHw",
#             database="0NMKbNP49w")
    #if mysql is local
            host='localhost',
            user='root',
            password="minyak23",
            database="newstockmarket")
    except Error as e:
        print(e)
        
#--------------------------------------------------------------------------------------------------------------------------------------------------
ftable = "stock_fundamental"
ovtable = "stock_overview"
fintable = "financial_report"
cashtable = "cashflow"
incometable = "income_statement"
balancetable = "balance_sheet"     

droptable_default = ( "DROP TABLE {table}"
                   )

db = connect()
cursor = db.cursor()

try :
    cursor.execute(droptable_default.format(table=ftable))
    cursor.execute(droptable_default.format(table=ovtable))
    cursor.execute(droptable_default.format(table=fintable))
    cursor.execute(droptable_default.format(table=cashtable))
    cursor.execute(droptable_default.format(table=incometable))
    cursor.execute(droptable_default.format(table=balancetable))    
    print ("Success Drop All Table")
except mysql.Error as err:
    print("Error Code:", err.errno)
    print("SQLSTATE", err.sqlstate)
    print("Message", err.msg)
    
db.commit()
db.close()
